# %% [markdown]
# #                      TEXT SUMMERIZATION(MINOR PROJECT)

# %%
#pip install numpy

# %%
#pip install scipy

# %%
#pip install gensim

# %%
#pip install beautifulsoup4

# %%
#pip install nltk
import nltk
#nltk.download('stopwords')

# %%
#pip install lxml

# %%
import bs4 as bs  
import urllib.request  
import re

scraped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Java_(software_platform)')  
article = scraped_data.read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:  
    article_text += p.text

# %% [markdown]
# # Preprocessing

# %%
# Removing Square Brackets and Extra Spaces
article_text = re.sub(r'\[[0-9]*\]', ' ', article_text)  
article_text = re.sub(r'\s+', ' ', article_text)

# %%
article_text
# Out:
# '11.0.3 (April 3, 2019; 3 months ago (2019-04-03) ) [±] Java is a set of computer software and specifications developed by James Gosling at Sun Microsystems, which was later acquired by the Oracle Corporation, that provides a system for developing application software and deploying it in a cross-platform computing environment. Java is used in a wide variety of computing platforms from embedded devices and mobile phones to enterprise servers and supercomputers. Java applets, which are less common than standalone Java applications, were commonly run in secure, sandboxed environments to provide many features of native applications through being embedded in HTML pages. It\'s still possible to run Java in web browsers after most of them having dropped support for Java\'s VM. Writing in the Java programming language is the primary way to produce code that will be deployed as byte code in a Java virtual machine (JVM); byte code compilers are also available for other languages, including Ada, JavaScript, Python, and Ruby. In addition, several languages have been designed to run natively on the JVM, including Clojure, Groovy, and Scala. Java syntax borrows heavily from C and C++, but object-oriented features are modeled after Smalltalk and Objective-C. Java eschews certain low-level constructs such as pointers and has a very simple memory model where objects are allocated on the heap (while some implementations e.g. all currently supported by Oracle, may use escape analysis optimization to allocating on the stack instead) and all variables of object types are references. Memory management is handled through integrated automatic garbage collection performed by the JVM. On November 13, 2006, Sun Microsystems made the bulk of its implementation of Java available under the GNU General Public License (GPL). The latest versions are Java 12, released in March 2019, and Java 11, a currently supported long-term support (LTS) version ("Oracle Customers will receive Oracle Premier Support"), released on September 25, 2018; Oracle released for the "legacy" Java 8 LTS the last free "public update" in January 2019 for commercial use, while it will otherwise still support Java 8 with public updates for personal use up to at least December 2020. Oracle (and others) "highly recommend that you uninstall older versions of Java", because of serious risks due to unresolved security issues. Since Java 9 (and 10) is no longer supported, Oracle advises its users to "immediately transition" to Java 11 (Java 12 is also an non-LTS option). Oracle released the last public update for the legacy Java 8 LTS, which is free for commercial use, in January 2019. Java 8 will be supported with public updates for personal use up to at least December 2020. Oracle and others "highly recommend that you uninstall older versions of Java" because of serious risks due to unresolved security issues. Oracle extended support for Java 6 ended in December 2018. The Java platform is a suite of programs that facilitate developing and running programs written in the Java programming language. A Java platform will include an execution engine (called a virtual machine), a compiler and a set of libraries; there may also be additional servers and alternative libraries that depend on the requirements. Java is not specific to any processor or operating system as Java platforms have been implemented for a wide variety of hardware and operating systems with a view to enable Java programs to run identically on all of them. Different platforms target different classes of device and application domains: The Java platform consists of several programs, each of which provides a portion of its overall capabilities. For example, the Java compiler, which converts Java source code into Java bytecode (an intermediate language for the JVM), is provided as part of the Java Development Kit (JDK). The Java Runtime Environment (JRE), complementing the JVM with a just-in-time (JIT) compiler, converts intermediat ...

# %%
# Removing special characters and digits
formatted_article_text = re.sub('[^a-zA-Z]', ' ', article_text )  
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

# %%
formatted_article_text
# Out:
# ' April months ago Java is a set of computer software and specifications developed by James Gosling at Sun Microsystems which was later acquired by the Oracle Corporation that provides a system for developing application software and deploying it in a cross platform computing environment Java is used in a wide variety of computing platforms from embedded devices and mobile phones to enterprise servers and supercomputers Java applets which are less common than standalone Java applications were commonly run in secure sandboxed environments to provide many features of native applications through being embedded in HTML pages It s still possible to run Java in web browsers after most of them having dropped support for Java s VM Writing in the Java programming language is the primary way to produce code that will be deployed as byte code in a Java virtual machine JVM byte code compilers are also available for other languages including Ada JavaScript Python and Ruby In addition several languages have been designed to run natively on the JVM including Clojure Groovy and Scala Java syntax borrows heavily from C and C but object oriented features are modeled after Smalltalk and Objective C Java eschews certain low level constructs such as pointers and has a very simple memory model where objects are allocated on the heap while some implementations e g all currently supported by Oracle may use escape analysis optimization to allocating on the stack instead and all variables of object types are references Memory management is handled through integrated automatic garbage collection performed by the JVM On November Sun Microsystems made the bulk of its implementation of Java available under the GNU General Public License GPL The latest versions are Java released in March and Java a currently supported long term support LTS version Oracle Customers will receive Oracle Premier Support released on September Oracle released for the legacy Java LTS the last free public update in January for commercial use while it will otherwise still support Java with public updates for personal use up to at least December Oracle and others highly recommend that you uninstall older versions of Java because of serious risks due to unresolved security issues Since Java and is no longer supported Oracle advises its users to immediately transition to Java Java is also an non LTS option Oracle released the last public update for the legacy Java LTS which is free for commercial use in January Java will be supported with public updates for personal use up to at least December Oracle and others highly recommend that you uninstall older versions of Java because of serious risks due to unresolved security issues Oracle extended support for Java ended in December The Java platform is a suite of programs that facilitate developing and running programs written in the Java programming language A Java platform will include an execution engine called a virtual machine a compiler and a set of libraries there may also be additional servers and alternative libraries that depend on the requirements Java is not specific to any processor or operating system as Java platforms have been implemented for a wide variety of hardware and operating systems with a view to enable Java programs to run identically on all of them Different platforms target different classes of device and application domains The Java platform consists of several programs each of which provides a portion of its overall capabilities For example the Java compiler which converts Java source code into Java bytecode an intermediate language for the JVM is provided as part of the Java Development Kit JDK The Java Runtime Environment JRE complementing the JVM with a just in time JIT compiler converts intermediate bytecode into native machine code on the fly The Java platform also includes an extensive set of libraries The essential components in the platform are the Java language compiler the libraries and the runtime en ...

# %% [markdown]
# # converting text to sentences

# %%
sentence_list = nltk.sent_tokenize(article_text)

# %% [markdown]
# # Finding Weighted Frequency of Occurrence

# %%
stopwords = nltk.corpus.stopwords.words('english')

word_frequencies = {}  
for word in nltk.word_tokenize(formatted_article_text):  
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
maximum_frequncy = max(word_frequencies.values())

for word in word_frequencies.keys():  
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %%
maximum_frequncy
# Out:
# 193

# %%
word_frequencies
# Out:
# {'April': 0.015544041450777202,
#  'months': 0.0051813471502590676,
#  'ago': 0.0051813471502590676,
#  'Java': 1.0,
#  'set': 0.05181347150259067,
#  'computer': 0.02072538860103627,
#  'software': 0.08290155440414508,
#  'specifications': 0.0051813471502590676,
#  'developed': 0.015544041450777202,
#  'James': 0.010362694300518135,
#  'Gosling': 0.02072538860103627,
#  'Sun': 0.17098445595854922,
#  'Microsystems': 0.031088082901554404,
#  'later': 0.015544041450777202,
#  'acquired': 0.0051813471502590676,
#  'Oracle': 0.10362694300518134,
#  'Corporation': 0.010362694300518135,
#  'provides': 0.025906735751295335,
#  'system': 0.06735751295336788,
#  'developing': 0.02072538860103627,
#  'application': 0.025906735751295335,
#  'deploying': 0.0051813471502590676,
#  'cross': 0.015544041450777202,
#  'platform': 0.21243523316062177,
#  'computing': 0.010362694300518135,
#  'environment': 0.03626943005181347,
#  'used': 0.046632124352331605,
#  'wide': 0.010362694300518135,
#  'variety': 0.010362694300518135,
#  'platforms': 0.03626943005181347,
#  'embedded': 0.015544041450777202,
#  'devices': 0.02072538860103627,
#  'mobile': 0.015544041450777202,
#  'phones': 0.010362694300518135,
#  'enterprise': 0.010362694300518135,
#  'servers': 0.010362694300518135,
#  'supercomputers': 0.0051813471502590676,
#  'applets': 0.015544041450777202,
#  'less': 0.015544041450777202,
#  'common': 0.010362694300518135,
#  'standalone': 0.0051813471502590676,
#  'applications': 0.05181347150259067,
#  'commonly': 0.015544041450777202,
#  'run': 0.07772020725388601,
#  'secure': 0.015544041450777202,
#  'sandboxed': 0.010362694300518135,
#  'environments': 0.010362694300518135,
#  'provide': 0.025906735751295335,
#  'many': 0.07772020725388601,
#  'features': 0.04145077720207254,
#  'native': 0.07253886010362694,
#  'HTML': 0.0051813471502590676,
#  'pages': 0.0051813471502590676,
#  'It': 0.04145077720207254,
#  'still': 0.031088082901554404,
#  'possible': 0.025906735751295335,
#  'web': 0.046632124352331605,
#  'browsers': 0.03626943005181347,
#  'dropped': 0.02072538860103627,
#  'support': 0.08290155440414508,
#  'VM': 0.031088082901554404,
#  'Writing': 0.0051813471502590676,
#  'programming': 0.05181347150259067,
#  'language': 0.17098445595854922,
#  'primary': 0.0051813471502590676,
#  'way': 0.02072538860103627,
#  'produce': 0.010362694300518135,
#  'code': 0.13471502590673576,
#  'deployed': 0.0051813471502590676,
#  'byte': 0.010362694300518135,
#  'virtual': 0.05181347150259067,
#  'machine': 0.05181347150259067,
#  'JVM': 0.10880829015544041,
#  'compilers': 0.02072538860103627,
#  'also': 0.06735751295336788,
#  'available': 0.04145077720207254,
#  'languages': 0.06217616580310881,
#  'including': 0.05699481865284974,
#  'Ada': 0.0051813471502590676,
#  'JavaScript': 0.02072538860103627,
#  'Python': 0.0051813471502590676,
#  'Ruby': 0.0051813471502590676,
#  'In': 0.07253886010362694,
#  'addition': 0.02072538860103627,
#  'several': 0.031088082901554404,
#  'designed': 0.015544041450777202,
#  'natively': 0.0051813471502590676,
#  'Clojure': 0.0051813471502590676,
#  'Groovy': 0.0051813471502590676,
#  'Scala': 0.0051813471502590676,
#  'syntax': 0.0051813471502590676,
#  'borrows': 0.0051813471502590676,
#  'heavily': 0.015544041450777202,
#  'C': 0.08808290155440414,
#  'object': 0.015544041450777202,
#  'oriented': 0.010362694300518135,
#  'modeled': 0.010362694300518135,
#  'Smalltalk': 0.0051813471502590676,
#  'Objective': 0.0051813471502590676,
#  'eschews': 0.0051813471502590676,
#  'certain': 0.015544041450777202,
#  'low': 0.0051813471502590676,
#  'level': 0.010362694300518135,
#  'constructs': 0.0051813471502590676,
#  'pointers': 0.0051813471502590676,
#  'simple': 0.010362694300518135,
#  'memory': 0.02072538860103627,
#  'model': 0.015544041450777202,
#  'objects': 0.0051813471502590676,
#  'allocated': 0.0051813471502590676,
#  'heap': 0.0051813471502590676,
#  'implementations': 0.05699481865284974,
#  'e': 0.04145077720207254,
#  'g': 0.02072538860103627,
#  'currently': 0.015544041450777202,
#  'supported': 0.05699481865284974,
#  'may': 0.02072538860103627,
#  'use': 0.09326424870466321,
#  'escape': 0.0051813471502590676,
#  'analysis': 0.0051813471502590676,
#  'optimization': 0.0051813471502590676,
#  'allocating': 0.0051813471502590676,
#  'stack': 0.0051813471502590676,
#  'instead': 0.015544041450777202,
#  'variables': 0.0051813471502590676,
#  'types': 0.031088082901554404,
#  'references': 0.0051813471502590676,
#  'Memory': 0.0051813471502590676,
#  'management': 0.0051813471502590676,
#  'handled': 0.010362694300518135,
#  'integrated': 0.015544041450777202,
#  'automatic': 0.010362694300518135,
#  'garbage': 0.015544041450777202,
#  'collection': 0.010362694300518135,
#  'performed': 0.0051813471502590676,
#  'On': 0.025906735751295335,
#  'November': 0.015544041450777202,
#  'made': 0.031088082901554404,
#  'bulk': 0.0051813471502590676,
#  'implementation': 0.031088082901554404,
#  'GNU': 0.031088082901554404,
#  'General': 0.02072538860103627,
#  'Public': 0.02072538860103627,
#  'License': 0.02072538860103627,
#  'GPL': 0.025906735751295335,
#  'The': 0.18652849740932642,
#  'latest': 0.0051813471502590676,
#  'versions': 0.03626943005181347,
#  'released': 0.08290155440414508,
#  'March': 0.02072538860103627,
#  'long': 0.010362694300518135,
#  'term': 0.0051813471502590676,
#  'LTS': 0.031088082901554404,
#  'version': 0.08808290155440414,
#  'Customers': 0.0051813471502590676,
#  'receive': 0.0051813471502590676,
#  'Premier': 0.0051813471502590676,
#  'Support': 0.0051813471502590676,
#  'September': 0.02072538860103627,
#  'legacy': 0.010362694300518135,
#  'last': 0.015544041450777202,
#  'free': 0.06735751295336788,
#  'public': 0.03626943005181347,
#  'update': 0.02072538860103627,
#  'January': 0.03626943005181347,
#  'commercial': 0.010362694300518135,
#  'otherwise': 0.0051813471502590676,
#  'updates': 0.02072538860103627,
#  'personal': 0.015544041450777202,
#  'least': 0.02072538860103627,
#  'December': 0.031088082901554404,
#  'others': 0.02072538860103627,
#  'highly': 0.025906735751295335,
#  'recommend': 0.015544041450777202,
#  'uninstall': 0.02072538860103627,
#  'older': 0.010362694300518135,
#  'serious': 0.015544041450777202,
#  'risks': 0.010362694300518135,
#  'due': 0.015544041450777202,
#  'unresolved': 0.010362694300518135,
#  'security': 0.06217616580310881,
#  'issues': 0.02072538860103627,
#  'Since': 0.02072538860103627,
#  'longer': 0.02072538860103627,
#  'advises': 0.0051813471502590676,
#  'users': 0.03626943005181347,
#  'immediately': 0.0051813471502590676,
#  'transition': 0.0051813471502590676,
#  'non': 0.0051813471502590676,
#  'option': 0.015544041450777202,
#  'extended': 0.02072538860103627,
#  'ended': 0.0051813471502590676,
#  'suite': 0.0051813471502590676,
#  'programs': 0.05699481865284974,
#  'facilitate': 0.0051813471502590676,
#  'running': 0.02072538860103627,
#  'written': 0.02072538860103627,
#  'A': 0.02072538860103627,
#  'include': 0.03626943005181347,
#  'execution': 0.015544041450777202,
#  'engine': 0.010362694300518135,
#  'called': 0.05181347150259067,
#  'compiler': 0.06217616580310881,
#  'libraries': 0.09326424870466321,
#  'additional': 0.010362694300518135,
#  'alternative': 0.02072538860103627,
#  'depend': 0.010362694300518135,
#  'requirements': 0.015544041450777202,
#  'specific': 0.02072538860103627,
#  'processor': 0.015544041450777202,
#  'operating': 0.05699481865284974,
#  'implemented': 0.015544041450777202,
#  'hardware': 0.025906735751295335,
#  'systems': 0.031088082901554404,
#  'view': 0.0051813471502590676,
#  'enable': 0.0051813471502590676,
#  'identically': 0.0051813471502590676,
#  'Different': 0.0051813471502590676,
#  'target': 0.015544041450777202,
#  'different': 0.02072538860103627,
#  'classes': 0.05181347150259067,
#  'device': 0.010362694300518135,
#  'domains': 0.0051813471502590676,
#  'consists': 0.0051813471502590676,
#  'portion': 0.0051813471502590676,
#  'overall': 0.0051813471502590676,
#  'capabilities': 0.010362694300518135,
#  'For': 0.025906735751295335,
#  'example': 0.015544041450777202,
#  'converts': 0.010362694300518135,
#  'source': 0.07772020725388601,
#  'bytecode': 0.05699481865284974,
#  'intermediate': 0.02072538860103627,
#  'provided': 0.02072538860103627,
#  'part': 0.015544041450777202,
#  'Development': 0.015544041450777202,
#  'Kit': 0.02072538860103627,
#  'JDK': 0.06217616580310881,
#  'Runtime': 0.031088082901554404,
#  'Environment': 0.031088082901554404,
#  'JRE': 0.046632124352331605,
#  'complementing': 0.0051813471502590676,
#  'time': 0.06217616580310881,
#  'JIT': 0.03626943005181347,
#  'fly': 0.0051813471502590676,
#  'includes': 0.031088082901554404,
#  'extensive': 0.010362694300518135,
#  'essential': 0.0051813471502590676,
#  'components': 0.02072538860103627,
#  'runtime': 0.05699481865284974,
#  'executes': 0.015544041450777202,
#  'according': 0.0051813471502590676,
#  'rules': 0.0051813471502590676,
#  'laid': 0.0051813471502590676,
#  'specification': 0.015544041450777202,
#  'heart': 0.0051813471502590676,
#  'concept': 0.010362694300518135,
#  'This': 0.06217616580310881,
#  'matter': 0.0051813471502590676,
#  'program': 0.025906735751295335,
#  'However': 0.031088082901554404,
#  'new': 0.08290155440414508,
#  'earlier': 0.0051813471502590676,
#  'small': 0.03626943005181347,
#  'changes': 0.05699481865284974,
#  'meaning': 0.0051813471502590676,
#  'general': 0.0051813471502590676,
#  'forward': 0.010362694300518135,
#  'compatible': 0.015544041450777202,
#  'There': 0.0051813471502590676,
#  'Just': 0.0051813471502590676,
#  'Time': 0.02072538860103627,
#  'within': 0.02072538860103627,
#  'Virtual': 0.010362694300518135,
#  'Machine': 0.0051813471502590676,
#  'translates': 0.0051813471502590676,
#  'instructions': 0.0051813471502590676,
#  'caches': 0.0051813471502590676,
#  'permits': 0.0051813471502590676,
#  'means': 0.0051813471502590676,
#  'short': 0.0051813471502590676,
#  'delay': 0.0051813471502590676,
#  'loading': 0.010362694300518135,
#  'warmed': 0.0051813471502590676,
#  'mostly': 0.015544041450777202,
#  'compiled': 0.010362694300518135,
#  'tend': 0.0051813471502590676,
#  'fast': 0.0051813471502590676,
#  'included': 0.031088082901554404,
#  'interpreter': 0.0051813471502590676,
#  'Although': 0.015544041450777202,
#  'independent': 0.0051813471502590676,
#  'Machines': 0.0051813471502590676,
#  'execute': 0.010362694300518135,
#  'Every': 0.0051813471502590676,
#  'modern': 0.010362694300518135,
#  'OSs': 0.0051813471502590676,
#  'large': 0.025906735751295335,
#  'body': 0.0051813471502590676,
#  'reusable': 0.010362694300518135,
#  'simplify': 0.0051813471502590676,
#  'programmer': 0.010362694300518135,
#  'job': 0.0051813471502590676,
#  'typically': 0.015544041450777202,
#  'dynamically': 0.0051813471502590676,
#  'loadable': 0.0051813471502590676,
#  'call': 0.0051813471502590676,
#  'Because': 0.015544041450777202,
#  'dependent': 0.0051813471502590676,
#  'rely': 0.0051813471502590676,
#  'pre': 0.0051813471502590676,
#  'existing': 0.02072538860103627,
#  'OS': 0.02072538860103627,
#  'Instead': 0.0051813471502590676,
#  'comprehensive': 0.0051813471502590676,
#  'standard': 0.025906735751295335,
#  'class': 0.05181347150259067,
#  'containing': 0.0051813471502590676,
#  'functions': 0.015544041450777202,
#  'found': 0.02072538860103627,
#  'Most': 0.0051813471502590676,
#  'library': 0.05181347150259067,
#  'instance': 0.010362694300518135,
#  'Swing': 0.015544041450777202,
#  'paints': 0.0051813471502590676,
#  'user': 0.06735751295336788,
#  'interface': 0.03626943005181347,
#  'handles': 0.0051813471502590676,
#  'events': 0.0051813471502590676,
#  'eliminating': 0.0051813471502590676,
#  'subtle': 0.0051813471502590676,
#  'differences': 0.010362694300518135,
#  'handle': 0.010362694300518135,
#  'serve': 0.0051813471502590676,
#  'three': 0.02072538860103627,
#  'purposes': 0.0051813471502590676,
#  'First': 0.0051813471502590676,
#  'like': 0.015544041450777202,
#  'well': 0.025906735751295335,
#  'known': 0.0051813471502590676,
#  'perform': 0.010362694300518135,
#  'tasks': 0.02072538860103627,
#  'maintaining': 0.0051813471502590676,
#  'lists': 0.0051813471502590676,
#  'items': 0.0051813471502590676,
#  'performing': 0.0051813471502590676,
#  'complex': 0.010362694300518135,
#  'string': 0.0051813471502590676,
#  'parsing': 0.0051813471502590676,
#  'Second': 0.0051813471502590676,
#  'abstract': 0.0051813471502590676,
#  'would': 0.04145077720207254,
#  'normally': 0.0051813471502590676,
#  'Tasks': 0.0051813471502590676,
#  'network': 0.010362694300518135,
#  'access': 0.025906735751295335,
#  'file': 0.015544041450777202,
#  'often': 0.010362694300518135,
#  'intertwined': 0.0051813471502590676,
#  'distinctive': 0.0051813471502590676,
#  'java': 0.010362694300518135,
#  'net': 0.0051813471502590676,
#  'io': 0.0051813471502590676,
#  'implement': 0.0051813471502590676,
#  'abstraction': 0.0051813471502590676,
#  'layer': 0.0051813471502590676,
#  'Finally': 0.010362694300518135,
#  'underlying': 0.0051813471502590676,
#  'expects': 0.0051813471502590676,
#  'work': 0.015544041450777202,
#  'gracefully': 0.0051813471502590676,
#  'absent': 0.0051813471502590676,
#  'either': 0.02072538860103627,
#  'emulation': 0.0051813471502590676,
#  'substitute': 0.0051813471502590676,
#  'providing': 0.010362694300518135,
#  'consistent': 0.0051813471502590676,
#  'check': 0.0051813471502590676,
#  'presence': 0.0051813471502590676,
#  'feature': 0.010362694300518135,
#  'word': 0.0051813471502590676,
#  'alone': 0.0051813471502590676,
#  'usually': 0.0051813471502590676,
#  'refers': 0.010362694300518135,
#  'Programming': 0.0051813471502590676,
#  'outside': 0.010362694300518135,
#  'scope': 0.0051813471502590676,
#  'phrase': 0.0051813471502590676,
#  'although': 0.015544041450777202,
#  'listed': 0.0051813471502590676,
#  'core': 0.02072538860103627,
#  'therefore': 0.015544041450777202,
#  'considered': 0.02072538860103627,
#  'single': 0.010362694300518135,
#  'unit': 0.010362694300518135,
#  'effort': 0.0051813471502590676,
#  'clearly': 0.0051813471502590676,
#  'treat': 0.0051813471502590676,
#  'separate': 0.010362694300518135,
#  'entities': 0.0051813471502590676,
#  'Third': 0.0051813471502590676,
#  'parties': 0.010362694300518135,
#  'produced': 0.010362694300518135,
#  'interpreters': 0.0051813471502590676,
#  'Some': 0.015544041450777202,
#  'extensions': 0.0051813471502590676,
#  'These': 0.02072538860103627,
#  'success': 0.0051813471502590676,
#  'write': 0.0051813471502590676,
#  'anywhere': 0.0051813471502590676,
#  'led': 0.015544041450777202,
#  'similar': 0.010362694300518135,
#  'efforts': 0.0051813471502590676,
#  'notably': 0.0051813471502590676,
#  'NET': 0.03626943005181347,
#  'Framework': 0.010362694300518135,
#  'appearing': 0.0051813471502590676,
#  'since': 0.04145077720207254,
#  'incorporates': 0.0051813471502590676,
#  'successful': 0.0051813471502590676,
#  'aspects': 0.0051813471502590676,
#  'complete': 0.010362694300518135,
#  'form': 0.010362694300518135,
#  'Microsoft': 0.025906735751295335,
#  'fully': 0.025906735751295335,
#  'Windows': 0.05181347150259067,
#  'whereas': 0.0051813471502590676,
#  'built': 0.010362694300518135,
#  'ground': 0.0051813471502590676,
#  'multiple': 0.0051813471502590676,
#  'initially': 0.0051813471502590676,
#  'Visual': 0.025906735751295335,
#  'J': 0.08290155440414508,
#  'formerly': 0.010362694300518135,
#  'named': 0.015544041450777202,
#  'incompatible': 0.0051813471502590676,
#  'associated': 0.0051813471502590676,
#  'dates': 0.0051813471502590676,
#  'old': 0.0051813471502590676,
#  'reasons': 0.010362694300518135,
#  'transitional': 0.0051813471502590676,
#  'switch': 0.010362694300518135,
#  'first': 0.05699481865284974,
#  'discontinued': 0.0051813471502590676,
#  'release': 0.046632124352331605,
#  'Studio': 0.010362694300518135,
#  'shipping': 0.0051813471502590676,
#  'per': 0.0051813471502590676,
#  'product': 0.010362694300518135,
#  'life': 0.0051813471502590676,
#  'cycle': 0.0051813471502590676,
#  'strategy': 0.0051813471502590676,
#  'citation': 0.025906735751295335,
#  'needed': 0.031088082901554404,
#  'aimed': 0.010362694300518135,
#  'developers': 0.010362694300518135,
#  'introduction': 0.010362694300518135,
#  'far': 0.010362694300518135,
#  'widely': 0.010362694300518135,
#  'development': 0.031088082901554404,
#  'kit': 0.0051813471502590676,
#  'SDK': 0.0051813471502590676,
#  'contains': 0.0051813471502590676,
#  'full': 0.010362694300518135,
#  'copy': 0.0051813471502590676,
#  'important': 0.010362694300518135,
#  'tools': 0.015544041450777202,
#  'began': 0.010362694300518135,
#  'internal': 0.010362694300518135,
#  'project': 0.015544041450777202,
#  'Engineer': 0.0051813471502590676,
#  'Patrick': 0.0051813471502590676,
#  'Naughton': 0.031088082901554404,
#  'become': 0.046632124352331605,
#  'increasingly': 0.0051813471502590676,
#  'frustrated': 0.0051813471502590676,
#  'state': 0.0051813471502590676,
#  'interfaces': 0.0051813471502590676,
#  'APIs': 0.015544041450777202,
#  'NeWS': 0.0051813471502590676,
#  'organization': 0.0051813471502590676,
#  'informed': 0.0051813471502590676,
#  'Scott': 0.0051813471502590676,
#  'McNealy': 0.015544041450777202,
#  'plan': 0.0051813471502590676,
#  'leaving': 0.0051813471502590676,
#  'moving': 0.0051813471502590676,
#  'NeXT': 0.0051813471502590676,
#  'asked': 0.0051813471502590676,
#  'pretend': 0.0051813471502590676,
#  'God': 0.0051813471502590676,
#  'send': 0.0051813471502590676,
#  'mail': 0.0051813471502590676,
#  'explaining': 0.0051813471502590676,
#  'fix': 0.0051813471502590676,
#  'company': 0.015544041450777202,
#  'envisioned': 0.015544041450777202,
#  'creation': 0.010362694300518135,
#  'team': 0.03626943005181347,
#  'could': 0.031088082901554404,
#  'autonomously': 0.0051813471502590676,
#  'without': 0.025906735751295335,
#  'bureaucracy': 0.0051813471502590676,
#  'stalling': 0.0051813471502590676,
#  'projects': 0.010362694300518135,
#  'forwarded': 0.0051813471502590676,
#  'message': 0.0051813471502590676,
#  'people': 0.010362694300518135,
#  'Stealth': 0.010362694300518135,
#  'Project': 0.025906735751295335,
#  'started': 0.0051813471502590676,
#  'soon': 0.010362694300518135,
#  'renamed': 0.015544041450777202,
#  'Green': 0.015544041450777202,
#  'Mike': 0.0051813471502590676,
#  'Sheridan': 0.0051813471502590676,
#  'joining': 0.0051813471502590676,
#  'Together': 0.0051813471502590676,
#  'engineers': 0.010362694300518135,
#  'office': 0.010362694300518135,
#  'Sand': 0.0051813471502590676,
#  'Hill': 0.0051813471502590676,
#  'Road': 0.0051813471502590676,
#  'Menlo': 0.0051813471502590676,
#  'Park': 0.0051813471502590676,
#  'California': 0.010362694300518135,
#  'They': 0.010362694300518135,
#  'develop': 0.010362694300518135,
#  'technology': 0.015544041450777202,
#  'next': 0.0051813471502590676,
#  'generation': 0.0051813471502590676,
#  'smart': 0.010362694300518135,
#  'appliances': 0.0051813471502590676,
#  'expected': 0.0051813471502590676,
#  'offer': 0.0051813471502590676,
#  'major': 0.010362694300518135,
#  'opportunities': 0.0051813471502590676,
#  'originally': 0.010362694300518135,
#  'using': 0.046632124352331605,
#  'rejected': 0.0051813471502590676,
#  'limited': 0.02072538860103627,
#  'resources': 0.010362694300518135,
#  'decided': 0.0051813471502590676,
#  'much': 0.010362694300518135,
#  'complexity': 0.0051813471502590676,
#  'developer': 0.0051813471502590676,
#  'errors': 0.0051813471502590676,
#  'lack': 0.015544041450777202,
#  'meant': 0.010362694300518135,
#  'programmers': 0.0051813471502590676,
#  'manually': 0.0051813471502590676,
#  'manage': 0.0051813471502590676,
#  'challenging': 0.0051813471502590676,
#  'error': 0.0051813471502590676,
#  'prone': 0.0051813471502590676,
#  'task': 0.0051813471502590676,
#  'worried': 0.0051813471502590676,
#  'portable': 0.0051813471502590676,
#  'facilities': 0.0051813471502590676,
#  'distributed': 0.0051813471502590676,
#  'threading': 0.0051813471502590676,
#  'wanted': 0.0051813471502590676,
#  'port': 0.0051813471502590676,
#  'easily': 0.0051813471502590676,
#  'Bill': 0.0051813471502590676,
#  'Joy': 0.010362694300518135,
#  'combining': 0.0051813471502590676,
#  'Mesa': 0.0051813471502590676,
#  'paper': 0.0051813471502590676,
#  'Further': 0.0051813471502590676,
#  'proposed': 0.010362694300518135,
#  'based': 0.010362694300518135,
#  'Initially': 0.0051813471502590676,
#  'attempted': 0.0051813471502590676,
#  'modify': 0.0051813471502590676,
#  'extend': 0.0051813471502590676,
#  'referred': 0.0051813471502590676,
#  'abandoned': 0.0051813471502590676,
#  'favor': 0.0051813471502590676,
#  'creating': 0.0051813471502590676,
#  'Oak': 0.025906735751295335,
#  'tree': 0.0051813471502590676,
#  'stood': 0.0051813471502590676,
#  'By': 0.0051813471502590676,
#  'summer': 0.0051813471502590676,
#  'demonstrate': 0.0051813471502590676,
#  'portions': 0.0051813471502590676,
#  'Their': 0.0051813471502590676,
#  'demonstration': 0.0051813471502590676,
#  'focused': 0.0051813471502590676,
#  'building': 0.010362694300518135,
#  'digital': 0.0051813471502590676,
#  'assistant': 0.0051813471502590676,
#  'PDA': 0.0051813471502590676,
#  'Star': 0.0051813471502590676,
#  'graphical': 0.015544041450777202,
#  'agent': 0.0051813471502590676,
#  'Duke': 0.025906735751295335,
#  'assist': 0.0051813471502590676,
#  'year': 0.010362694300518135,
#  'spun': 0.0051813471502590676,
#  'Firstperson': 0.02072538860103627,
#  'wholly': 0.0051813471502590676,
#  'owned': 0.0051813471502590676,
#  'subsidiary': 0.0051813471502590676,
#  'relocated': 0.0051813471502590676,
#  'Palo': 0.0051813471502590676,
#  'Alto': 0.0051813471502590676,
#  'interest': 0.015544041450777202,
#  'interactive': 0.010362694300518135,
#  'Warner': 0.0051813471502590676,
#  'issued': 0.0051813471502590676,
#  'request': 0.0051813471502590676,
#  'proposal': 0.010362694300518135,
#  'RFP': 0.0051813471502590676,
#  'top': 0.015544041450777202,
#  'box': 0.015544041450777202,
#  'changed': 0.0051813471502590676,
#  'responded': 0.0051813471502590676,
#  'cable': 0.010362694300518135,
#  'industry': 0.010362694300518135,
#  'felt': 0.010362694300518135,
#  'gave': 0.0051813471502590676,
#  'control': 0.010362694300518135,
#  'lost': 0.0051813471502590676,
#  'bid': 0.0051813471502590676,
#  'SGI': 0.0051813471502590676,
#  'An': 0.0051813471502590676,
#  'deal': 0.0051813471502590676,
#  'DO': 0.0051813471502590676,
#  'Company': 0.0051813471502590676,
#  'failed': 0.010362694300518135,
#  'materialize': 0.0051813471502590676,
#  'Unable': 0.0051813471502590676,
#  'generate': 0.0051813471502590676,
#  'television': 0.0051813471502590676,
#  'rolled': 0.0051813471502590676,
#  'back': 0.015544041450777202,
#  'June': 0.015544041450777202,
#  'July': 0.015544041450777202,
#  'days': 0.015544041450777202,
#  'brainstorming': 0.0051813471502590676,
#  'John': 0.0051813471502590676,
#  'Gage': 0.015544041450777202,
#  'Director': 0.0051813471502590676,
#  'Science': 0.0051813471502590676,
#  'Wayne': 0.0051813471502590676,
#  'Rosing': 0.0051813471502590676,
#  'Eric': 0.0051813471502590676,
#  'Schmidt': 0.0051813471502590676,
#  'targeted': 0.0051813471502590676,
#  'World': 0.0051813471502590676,
#  'Wide': 0.0051813471502590676,
#  'Web': 0.02072538860103627,
#  'advent': 0.0051813471502590676,
#  'Mosaic': 0.0051813471502590676,
#  'Internet': 0.010362694300518135,
#  'evolve': 0.0051813471502590676,
#  'medium': 0.0051813471502590676,
#  'TV': 0.0051813471502590676,
#  'As': 0.015544041450777202,
#  'prototype': 0.0051813471502590676,
#  'wrote': 0.0051813471502590676,
#  'browser': 0.05181347150259067,
#  'WebRunner': 0.0051813471502590676,
#  'movie': 0.0051813471502590676,
#  'Blade': 0.0051813471502590676,
#  'Runner': 0.0051813471502590676,
#  'HotJava': 0.010362694300518135,
#  'trademark': 0.0051813471502590676,
#  'search': 0.0051813471502590676,
#  'revealed': 0.0051813471502590676,
#  'Technology': 0.010362694300518135,
#  'name': 0.015544041450777202,
#  'became': 0.010362694300518135,
#  'download': 0.02072538860103627,
#  'came': 0.0051813471502590676,
#  'May': 0.015544041450777202,
#  'announced': 0.031088082901554404,
#  'SunWorld': 0.0051813471502590676,
#  'conference': 0.010362694300518135,
#  'Accompanying': 0.0051813471502590676,
#  'announcement': 0.010362694300518135,
#  'Marc': 0.0051813471502590676,
#  'Andreessen': 0.0051813471502590676,
#  'Executive': 0.0051813471502590676,
#  'Vice': 0.0051813471502590676,
#  'President': 0.0051813471502590676,
#  'Netscape': 0.010362694300518135,
#  'Communications': 0.0051813471502590676,
#  'unexpectedly': 0.0051813471502590676,
#  'formed': 0.0051813471502590676,
#  'JavaSoft': 0.0051813471502590676,
#  'group': 0.0051813471502590676,
#  'While': 0.02072538860103627,
#  'popular': 0.02072538860103627,
#  'server': 0.0051813471502590676,
#  'side': 0.010362694300518135,
#  'client': 0.010362694300518135,
#  'took': 0.0051813471502590676,
#  'Kotlin': 0.0051813471502590676,
#  'even': 0.010362694300518135,
#  'TeaVM': 0.0051813471502590676,
#  'undergone': 0.0051813471502590676,
#  'numerous': 0.010362694300518135,
#  'additions': 0.02072538860103627,
#  'packages': 0.0051813471502590676,
#  'SE': 0.09326424870466321,
#  'Community': 0.010362694300518135,
#  'Process': 0.010362694300518135,
#  'JCP': 0.010362694300518135,
#  'governed': 0.0051813471502590676,
#  'evolution': 0.0051813471502590676,
#  'Language': 0.010362694300518135,
#  'uses': 0.010362694300518135,
#  'Specification': 0.010362694300518135,
#  'Requests': 0.0051813471502590676,
#  'JSRs': 0.0051813471502590676,
#  'propose': 0.0051813471502590676,
#  'specify': 0.0051813471502590676,
#  'JLS': 0.010362694300518135,
#  'specifies': 0.0051813471502590676,
#  'managed': 0.0051813471502590676,
#  'JSR': 0.025906735751295335,
#  'February': 0.010362694300518135,
#  'Major': 0.015544041450777202,
#  'retooling': 0.0051813471502590676,
#  'AWT': 0.0051813471502590676,
#  'event': 0.0051813471502590676,
#  'inner': 0.0051813471502590676,
#  'added': 0.02072538860103627,
#  'JavaBeans': 0.0051813471502590676,
#  'JDBC': 0.0051813471502590676,
#  'Codename': 0.031088082901554404,
#  'Playground': 0.0051813471502590676,
#  'subsequent': 0.0051813471502590676,
#  'releases': 0.0051813471502590676,
#  'rebranded': 0.0051813471502590676,
#  'Platform': 0.031088082901554404,
#  'Standard': 0.015544041450777202,
#  'Edition': 0.02072538860103627,
#  'replaced': 0.010362694300518135,
#  'distinguish': 0.0051813471502590676,
#  'base': 0.0051813471502590676,
#  'EE': 0.0051813471502590676,
#  'Enterprise': 0.015544041450777202,
#  'ME': 0.015544041450777202,
#  'Micro': 0.0051813471502590676,
#  'reflection': 0.0051813471502590676,
#  'collections': 0.0051813471502590676,
#  'framework': 0.015544041450777202,
#  'IDL': 0.0051813471502590676,
#  'description': 0.0051813471502590676,
#  'CORBA': 0.0051813471502590676,
#  'interoperability': 0.0051813471502590676,
#  'integration': 0.0051813471502590676,
#  'API': 0.010362694300518135,
#  'Plug': 0.0051813471502590676,
#  'equipped': 0.0051813471502590676,
#  'Kestrel': 0.0051813471502590676,
#  'Notable': 0.010362694300518135,
#  'bundling': 0.010362694300518135,
#  'HotSpot': 0.02072538860103627,
#  'JavaSound': 0.0051813471502590676,
#  'Naming': 0.0051813471502590676,
#  'Directory': 0.0051813471502590676,
#  'Interface': 0.010362694300518135,
#  'JNDI': 0.0051813471502590676,
#  'Debugger': 0.010362694300518135,
#  'Architecture': 0.010362694300518135,
#  'JPDA': 0.010362694300518135,
#  'Merlin': 0.0051813471502590676,
#  'regular': 0.0051813471502590676,
#  'expressions': 0.010362694300518135,
#  'Perl': 0.0051813471502590676,
#  'exception': 0.0051813471502590676,
#  'chaining': 0.0051813471502590676,
#  'XML': 0.0051813471502590676,
#  'parser': 0.0051813471502590676,
#  'XSLT': 0.0051813471502590676,
#  'JAXP': 0.0051813471502590676,
#  'Start': 0.0051813471502590676,
#  'Tiger': 0.010362694300518135,
#  'numbered': 0.0051813471502590676,
#  'number': 0.010362694300518135,
#  'Developed': 0.0051813471502590676,
#  'significant': 0.010362694300518135,
#  'loop': 0.0051813471502590676,
#  'generics': 0.015544041450777202,
#  'autoboxing': 0.0051813471502590676,
#  'var': 0.0051813471502590676,
#  'args': 0.0051813471502590676,
#  'Mustang': 0.0051813471502590676,
#  'bundled': 0.015544041450777202,
#  'database': 0.0051813471502590676,
#  'manager': 0.0051813471502590676,
#  'facilitates': 0.0051813471502590676,
#  'scripting': 0.0051813471502590676,
#  'Mozilla': 0.0051813471502590676,
#  'Rhino': 0.0051813471502590676,
#  'Other': 0.0051813471502590676,
#  'pluggable': 0.0051813471502590676,
#  'annotations': 0.0051813471502590676,
#  'GUI': 0.0051813471502590676,
#  'improvements': 0.010362694300518135,
#  'UI': 0.0051813471502590676,
#  'enhancements': 0.0051813471502590676,
#  'look': 0.010362694300518135,
#  'feel': 0.0051813471502590676,
#  'Vista': 0.010362694300518135,
#  'Tool': 0.0051813471502590676,
#  'better': 0.0051813471502590676,
#  'monitoring': 0.0051813471502590676,
#  'troubleshooting': 0.0051813471502590676,
#  'Dolphin': 0.0051813471502590676,
#  'strings': 0.0051813471502590676,
#  'try': 0.0051813471502590676,
#  'type': 0.02072538860103627,
#  'inference': 0.0051813471502590676,
#  'generic': 0.0051813471502590676,
#  'dynamic': 0.0051813471502590676,
#  'among': 0.0051813471502590676,
#  'join': 0.0051813471502590676,
#  'fork': 0.0051813471502590676,
#  'improved': 0.010362694300518135,
#  'I': 0.02072538860103627,
#  'O': 0.0051813471502590676,
#  'protocols': 0.0051813471502590676,
#  'SCTP': 0.0051813471502590676,
#  'Update': 0.0051813471502590676,
#  'expiration': 0.0051813471502590676,
#  'date': 0.0051813471502590676,
#  'remotely': 0.0051813471502590676,
#  'exploitable': 0.0051813471502590676,
#  'bugs': 0.0051813471502590676,
#  'lambda': 0.0051813471502590676,
#  'closures': 0.0051813471502590676,
#  'default': 0.02072538860103627,
#  'methods': 0.015544041450777202,
#  'Nashorn': 0.0051813471502590676,
#  'Date': 0.0051813471502590676,
#  'inspired': 0.0051813471502590676,
#  'Joda': 0.0051813471502590676,
#  'removal': 0.0051813471502590676,
#  'PermGen': 0.0051813471502590676,
#  'officially': 0.0051813471502590676,
#  'XP': 0.015544041450777202,
#  'end': 0.02072538860103627,
#  'lifecycle': 0.0051813471502590676,
#  'recommended': 0.0051813471502590676,
#  'Previously': 0.0051813471502590676,
#  'unofficial': 0.0051813471502590676,
#  'manual': 0.0051813471502590676,
#  'installation': 0.015544041450777202,
#  'method': 0.0051813471502590676,
#  'described': 0.0051813471502590676,
#  'SP': 0.02072538860103627,
#  'functioning': 0.0051813471502590676,
#  'Server': 0.010362694300518135,
#  'R': 0.0051813471502590676,
#  'Ubuntu': 0.0051813471502590676,
#  'higher': 0.010362694300518135,
#  'OSes': 0.0051813471502590676,
#  'minimum': 0.0051813471502590676,
#  'certified': 0.010362694300518135,
#  'upped': 0.0051813471502590676,
#  'Explorer': 0.0051813471502590676,
#  'bit': 0.03626943005181347,
#  'compatibility': 0.010362694300518135,
#  'machines': 0.0051813471502590676,
#  'JVMs': 0.0051813471502590676,
#  'rapid': 0.0051813471502590676,
#  'adopted': 0.0051813471502590676,
#  'starting': 0.0051813471502590676,
#  'OpenJDK': 0.03626943005181347,
#  'represents': 0.0051813471502590676,
#  'dual': 0.0051813471502590676,
#  'licenses': 0.0051813471502590676,
#  'optional': 0.0051813471502590676,
#  'proprietary': 0.031088082901554404,
#  'license': 0.025906735751295335,
#  'modules': 0.0051813471502590676,
#  'unique': 0.0051813471502590676,
#  'licensed': 0.010362694300518135,
#  'two': 0.010362694300518135,
#  'collector': 0.0051813471502590676,
#  'Flight': 0.0051813471502590676,
#  'Recorder': 0.0051813471502590676,
#  'debug': 0.0051813471502590676,
#  'deep': 0.0051813471502590676,
#  'HTTP': 0.0051813471502590676,
#  'WebSocket': 0.0051813471502590676,
#  'years': 0.015544041450777202,
#  'grown': 0.0051813471502590676,
#  'hundred': 0.0051813471502590676,
#  'thousand': 0.0051813471502590676,
#  'Entire': 0.0051813471502590676,
#  'D': 0.010362694300518135,
#  'evolved': 0.0051813471502590676,
#  'original': 0.0051813471502590676,
#  'deprecated': 0.010362694300518135,
#  'According': 0.010362694300518135,
#  'million': 0.0051813471502590676,
#  'PCs': 0.015544041450777202,
#  'sued': 0.0051813471502590676,
#  'adding': 0.0051813471502590676,
#  'making': 0.0051813471502590676,
#  'Apple': 0.010362694300518135,
#  'X': 0.0051813471502590676,
#  'prompts': 0.0051813471502590676,
#  'install': 0.010362694300518135,
#  'requiring': 0.010362694300518135,
#  'launched': 0.0051813471502590676,
#  'Many': 0.0051813471502590676,
#  'Linux': 0.015544041450777202,
#  'distributions': 0.010362694300518135,
#  'negating': 0.0051813471502590676,
#  'need': 0.015544041450777202,
#  'fairly': 0.010362694300518135,
#  'widespread': 0.0051813471502590676,
#  'desktop': 0.0051813471502590676,
#  'NetBeans': 0.0051813471502590676,
#  'Eclipse': 0.0051813471502590676,
#  'sharing': 0.0051813471502590676,
#  'clients': 0.0051813471502590676,
#  'LimeWire': 0.0051813471502590676,
#  'Vuze': 0.0051813471502590676,
#  'MATLAB': 0.0051813471502590676,
#  'mathematics': 0.0051813471502590676,
#  'rendering': 0.010362694300518135,
#  'high': 0.0051813471502590676,
#  'collaborative': 0.0051813471502590676,
#  'Lotus': 0.0051813471502590676,
#  'Notes': 0.0051813471502590676,
#  'plans': 0.0051813471502590676,
#  'deprecate': 0.0051813471502590676,
#  'separately': 0.0051813471502590676,
#  'installable': 0.0051813471502590676,
#  'plugin': 0.02072538860103627,
#  'remove': 0.010362694300518135,
#  'completely': 0.015544041450777202,
#  'future': 0.0051813471502590676,
#  'forcing': 0.0051813471502590676,
#  'competes': 0.0051813471502590676,
#  'Symbian': 0.0051813471502590676,
#  'BREW': 0.0051813471502590676,
#  'Compact': 0.0051813471502590676,
#  'diversity': 0.0051813471502590676,
#  'phone': 0.0051813471502590676,
#  'manufacturers': 0.010362694300518135,
#  'unified': 0.0051813471502590676,
#  'standards': 0.02072538860103627,
#  'suppliers': 0.0051813471502590676,
#  'MIDP': 0.015544041450777202,
#  'assumed': 0.0051813471502590676,
#  'screen': 0.0051813471502590676,
#  'size': 0.025906735751295335,
#  'audio': 0.010362694300518135,
#  'KB': 0.010362694300518135,
#  'limit': 0.0051813471502590676,
#  'recent': 0.015544041450777202,
#  'allows': 0.0051813471502590676,
#  'With': 0.0051813471502590676,
#  'handset': 0.0051813471502590676,
#  'designs': 0.0051813471502590676,
#  'improving': 0.0051813471502590676,
#  'rapidly': 0.0051813471502590676,
#  'relax': 0.0051813471502590676,
#  'limitations': 0.0051813471502590676,
#  'maximum': 0.0051813471502590676,
#  'Google': 0.010362694300518135,
#  'Android': 0.02072538860103627,
#  'ART': 0.0051813471502590676,
#  'Dalvik': 0.0051813471502590676,
#  'mainstay': 0.0051813471502590676,
#  'IT': 0.0051813471502590676,
#  'ways': 0.0051813471502590676,
#  'main': 0.0051813471502590676,
#  'driver': 0.0051813471502590676,
#  'open': 0.04145077720207254,
#  'Open': 0.010362694300518135,
#  'communities': 0.0051813471502590676,
#  'amount': 0.0051813471502590676,
#  'function': 0.010362694300518135,
#  'frameworks': 0.0051813471502590676,
#  'mascot': 0.0051813471502590676,
#  'When': 0.010362694300518135,
#  'graphics': 0.0051813471502590676,
#  'BSD': 0.0051813471502590676,
#  'personality': 0.0051813471502590676,
#  'created': 0.015544041450777202,
#  'every': 0.010362694300518135,
#  'Future': 0.0051813471502590676,
#  'Tech': 0.0051813471502590676,
#  'bigger': 0.0051813471502590676,
#  'nose': 0.0051813471502590676,
#  'jetpack': 0.0051813471502590676,
#  'blue': 0.0051813471502590676,
#  'wings': 0.0051813471502590676,
#  'de': 0.0051813471502590676,
#  ...}

# %% [markdown]
# # Calculating Sentence Scores

# %%
sentence_scores = {}  
for sent in sentence_list:  
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
sentence_scores
# Out:
# {'Java is used in a wide variety of computing platforms from embedded devices and mobile phones to enterprise servers and supercomputers.': 0.21243523316062177,
#  "It's still possible to run Java in web browsers after most of them having dropped support for Java's VM.": 0.3419689119170984,
#  'In addition, several languages have been designed to run natively on the JVM, including Clojure, Groovy, and Scala.': 0.2694300518134715,
#  'all currently supported by Oracle, may use escape analysis optimization to allocating on the stack instead) and all variables of object types are references.': 0.28497409326424866,
#  'Memory management is handled through integrated automatic garbage collection performed by the JVM.': 0.09326424870466321,
#  'On November 13, 2006, Sun Microsystems made the bulk of its implementation of Java available under the GNU General Public License (GPL).': 0.18652849740932642,
#  'Oracle (and others) "highly recommend that you uninstall older versions of Java", because of serious risks due to unresolved security issues.': 0.2746113989637306,
#  'Since Java 9 (and 10) is no longer supported, Oracle advises its users to "immediately transition" to Java 11 (Java 12 is also an non-LTS option).': 0.2849740932642487,
#  'Oracle released the last public update for the legacy Java 8 LTS, which is free for commercial use, in January 2019.': 0.3471502590673575,
#  'Java 8 will be supported with public updates for personal use up to at least December 2020.': 0.2538860103626943,
#  'Oracle and others "highly recommend that you uninstall older versions of Java" because of serious risks due to unresolved security issues.': 0.2746113989637306,
#  'Oracle extended support for Java 6 ended in December 2018.': 0.11917098445595856,
#  'The Java platform is a suite of programs that facilitate developing and running programs written in the Java programming language.': 0.6424870466321244,
#  'Different platforms target different classes of device and application domains: The Java platform consists of several programs, each of which provides a portion of its overall capabilities.': 0.5492227979274612,
#  'For example, the Java compiler, which converts Java source code into Java bytecode (an intermediate language for the JVM), is provided as part of the Java Development Kit (JDK).': 0.6632124352331606,
#  'The Java Runtime Environment (JRE), complementing the JVM with a just-in-time (JIT) compiler, converts intermediate bytecode into native machine code on the fly.': 0.5233160621761658,
#  'The Java platform also includes an extensive set of libraries.': 0.4766839378238342,
#  'The heart of the Java platform is the concept of a "virtual machine" that executes Java bytecode programs.': 0.48186528497409326,
#  'This bytecode is the same no matter what hardware or operating system the program is running under.': 0.25906735751295334,
#  'However, new versions, such as for Java 10 (and earlier), have made small changes, meaning the bytecode is in general only forward compatible.': 0.35233160621761656,
#  'There is a JIT (Just In Time) compiler within the Java Virtual Machine, or JVM.': 0.25906735751295334,
#  'The JIT compiler translates the Java bytecode into native processor instructions at run-time and caches the native code in memory during execution.': 0.4766839378238342,
#  'The use of bytecode as an intermediate language permits Java programs to run on any platform that has a virtual machine available.': 0.849740932642487,
#  "Since JRE version 1.2, Sun's JVM implementation has included a just-in-time compiler instead of an interpreter.": 0.2746113989637306,
#  'Although Java programs are cross-platform or platform independent, the code of the Java Virtual Machines (JVM) that execute these programs is not.': 0.5699481865284974,
#  'Every supported operating platform has its own JVM.': 0.33678756476683935,
#  "In most modern operating systems (OSs), a large body of reusable code is provided to simplify the programmer's job.": 0.3160621761658031,
#  'This code is typically provided as a set of dynamically loadable libraries that applications can call at runtime.': 0.4404145077720207,
#  'Because the Java platform is not dependent on any specific operating system, applications cannot rely on any of the pre-existing OS libraries.': 0.5233160621761659,
#  'Instead, the Java platform provides a comprehensive set of its own standard class libraries containing many of the same reusable functions commonly found in modern operating systems.': 0.7357512953367877,
#  'Most of the system library is also written in Java.': 0.21761658031088082,
#  'For instance, the Swing library paints the user interface and handles the events itself, eliminating many subtle differences between how different platforms handle components.': 0.36787564766839376,
#  'The Java class libraries serve three purposes within the Java platform.': 0.43005181347150256,
#  'Second, the class libraries provide an abstract interface to tasks that would normally depend heavily on the hardware and operating system.': 0.4559585492227979,
#  'Tasks such as network access and file access are often heavily intertwined with the distinctive implementations of each platform.': 0.40414507772020725,
#  'The java.net and java.io libraries implement an abstraction layer in native OS code, then provide a standard interface for the Java applications to perform those tasks.': 0.49740932642487046,
#  'The word "Java", alone, usually refers to Java programming language that was designed for use with the Java platform.': 0.6010362694300518,
#  'The language and runtime were therefore commonly considered a single unit.': 0.3005181347150259,
#  'Third parties have produced many compilers or interpreters that target the JVM.': 0.15544041450777202,
#  'Some of these are for existing languages, while others are for extensions to the Java language.': 0.2901554404145078,
#  ".NET in its complete form (Microsoft's implementation) is currently only fully available on Windows platforms, whereas Java is fully available on many platforms.": 0.3678756476683938,
#  'For these reasons, it is more of a transitional language to switch from Java to the .NET platform than it is a first class .NET language.': 0.6994818652849741,
#  'Visual J# was discontinued with the release of Microsoft Visual Studio 2008.': 0.05181347150259067,
#  'The existing version shipping with Visual Studio 2005 will be supported until 2015 as per the product life-cycle strategy.': 0.19170984455958548,
#  '[citation needed] The Java Development Kit (JDK) is a Sun product aimed at Java developers.': 0.14507772020725387,
#  'Since the introduction of Java, it has been by far the most widely used Java software development kit (SDK).': 0.2590673575129534,
#  '[citation needed] It contains a Java compiler, a full copy of the Java Runtime Environment (JRE), and many other important development tools.': 0.38860103626943004,
#  'The Java platform and language began as an internal project at Sun Microsystems in December 1990, providing an alternative to the C++/C programming languages.': 0.5751295336787564,
#  'Naughton envisioned the creation of a small team that could work autonomously without the bureaucracy that was stalling other Sun projects.': 0.19689119170984454,
#  'McNealy forwarded the message to other important people at Sun, and the Stealth Project started.': 0.05181347150259067,
#  'The Stealth Project was soon renamed to the Green Project, with James Gosling and Mike Sheridan joining Naughton.': 0.06217616580310881,
#  'Together with other engineers, they began work in a small office on Sand Hill Road in Menlo Park, California.': 0.08290155440414508,
#  'They aimed to develop new technology for programming next-generation smart appliances, which Sun expected to offer major new opportunities.': 0.29533678756476683,
#  'The team originally considered using C++, but rejected it for several reasons.': 0.1606217616580311,
#  'Because they were developing an embedded system with limited resources, they decided that C++ needed too much memory and that its complexity led to developer errors.': 0.233160621761658,
#  "The language's lack of garbage collection meant that programmers had to manually manage system memory, a challenging and error-prone task.": 0.3367875647668394,
#  "The team also worried about the C++ language's lack of portable facilities for security, distributed programming, and threading.": 0.4300518134715027,
#  'Finally, they wanted a platform that would port easily to all types of devices.': 0.3212435233160622,
#  'By the summer of 1992, the team could demonstrate portions of the new platform, including the Green OS, the Oak language, the libraries, and the hardware.': 0.7253886010362693,
#  'In November of that year, the Green Project was spun off to become Firstperson, a wholly owned subsidiary of Sun Microsystems, and the team relocated to Palo Alto, California.': 0.13471502590673576,
#  'However, the cable industry felt that their platform gave too much control to the user, so Firstperson lost their bid to SGI.': 0.3471502590673575,
#  'An additional deal with The 3DO Company for a set-top box also failed to materialize.': 0.12953367875647667,
#  'Unable to generate interest within the television industry, the company was rolled back into Sun.': 0.09326424870466322,
#  'They felt that with the advent of graphical web browsers like Mosaic the Internet could evolve into the same highly interactive medium that they had envisioned for cable TV.': 0.23316062176165803,
#  'As a prototype, Naughton wrote a small browser, WebRunner (named after the movie Blade Runner), renamed HotJava in 1995.': 0.13471502590673573,
#  'In 1994, Sun renamed the Oak language to Java after a trademark search revealed that Oak Technology used the name Oak.': 0.29015544041450775,
#  "Accompanying Gage's announcement, Marc Andreessen, Executive Vice President of Netscape Communications Corporation, unexpectedly announced that Netscape browsers would include Java support.": 0.2538860103626943,
#  'On January 9, 1996, Sun Microsystems formed the JavaSoft group to develop the technology.': 0.036269430051813475,
#  'While the so-called Java applets for web browsers no longer are the most popular use of Java (with it e.g.': 0.25388601036269426,
#  'Since J2SE 1.4 the Java Community Process (JCP) has governed the evolution of the Java Language.': 0.24870466321243523,
#  'The JCP uses Java Specification Requests (JSRs) to propose and specify additions and changes to the Java platform.': 0.3471502590673575,
#  'The Java Language Specification (JLS) specifies the language; changes to the JLS are managed under JSR 901.': 0.43523316062176165,
#  'Sun released JDK 1.1 on February 19, 1997.': 0.08290155440414508,
#  'Major additions included an extensive retooling of the AWT event model, inner classes added to the language, JavaBeans and JDBC.': 0.3471502590673575,
#  'Major additions included reflection, a collections framework, Java IDL (an interface description language implementation for CORBA interoperability), and the integration of the Swing graphical API into the core classes.': 0.4404145077720208,
#  "A Java Plug-in was released, and Sun's JVM was equipped with a JIT compiler for the first time.": 0.27979274611398963,
#  'J2SE 1.3 (May 8, 2000) – Codename Kestrel.': 0.02072538860103627,
#  'This became the first release of the Java platform developed under the Java Community Process as JSR 59.': 0.36787564766839376,
#  'Major changes included regular expressions modeled after Perl, exception chaining, an integrated XML parser and XSLT processor (JAXP), and Java Web Start.': 0.22797927461139894,
#  'It was originally numbered 1.5, which is still used as the internal version number.': 0.20207253886010362,
#  'Developed under JSR 176, Tiger added several significant new language features including the for-each loop, generics, autoboxing and var-args.': 0.45595854922279794,
#  'Java SE 6 (December 11, 2006) – Codename Mustang.': 0.010362694300518135,
#  "It was bundled with a database manager and facilitates the use of scripting languages with the JVM (such as JavaScript using Mozilla's Rhino engine).": 0.24870466321243523,
#  'As of this version, Sun replaced the name "J2SE" with Java SE and dropped the ".0" from the version number.': 0.24352331606217617,
#  'Java SE 7 (July 28, 2011) – Codename Dolphin.': 0.010362694300518135,
#  'This version developed under JSR 336.': 0.10362694300518134,
#  'It added many small language changes including strings in switch, try-with-resources and type inference for generic instance creation.': 0.4870466321243523,
#  'Java 7 Update 76 was released in January 2015, with expiration date April 14, 2015.': 0.12435233160621763,
#  'In June 2016, after the last public update of Java 7, "remotely exploitable" security bugs in Java 6, 7, and 8 were announced.': 0.20207253886010362,
#  'This version is not officially supported on the Windows XP platform.': 0.3626943005181347,
#  "However, due to the end of Java 7's lifecycle it is the recommended version for XP users.": 0.18134715025906734,
#  'Previously, only an unofficial manual installation method had been described for Windows XP SP3.': 0.036269430051813475,
#  'It refers to JDK8, the developing platform for Java that also includes a fully functioning Java Runtime Environment.': 0.48704663212435234,
#  'Java 8 is supported on Windows Server 2008 R2 SP1, Windows Vista SP2 and Windows 7 SP1, Ubuntu 12.04 LTS and higher (and some other OSes).': 0.08290155440414508,
#  'Java SE 9 and 10 had higher system requirements, i.e.': 0.10362694300518135,
#  'Windows 7 or Server 2012 (and web browser minimum certified is upped to Internet Explorer 11 or other web browsers), and Oracle dropped 32-bit compatibility for all platforms, i.e.': 0.27461139896373055,
#  'only Oracle\'s "64-bit Java virtual machines (JVMs) are certified".': 0.07772020725388601,
#  'Java SE 11 was released September 2018, the first LTS release since the rapid release model was adopted starting with version 9.': 0.4041450777202073,
#  'Java 11 features include two new garbage collector implementations, Flight Recorder to debug deep issues, a new HTTP client including WebSocket support.': 0.5233160621761658,
#  'Java SE 12 was released March 2019.': 0.09326424870466321,
#  'Entire new APIs, such as Swing and Java 2D, have evolved, and many of the original JDK 1.0 classes and methods have been deprecated.': 0.26424870466321243,
#  'According to Oracle in 2010, the Java Runtime Environment was found on over 850 million PCs.': 0.13471502590673573,
#  '[citation needed] Many Linux distributions include the OpenJDK runtime as the default virtual machine, negating the need to download the proprietary Oracle JRE.': 0.4352331606217617,
#  'Some Java applications are in fairly widespread desktop use, including the NetBeans and Eclipse integrated development environments, and file sharing clients such as LimeWire and Vuze.': 0.3160621761658031,
#  'Java is also used in the MATLAB mathematics programming environment, both for rendering the user interface and as part of the core system.': 0.4352331606217617,
#  'Java provides cross platform user interface for some high end collaborative applications such as Lotus Notes.': 0.45077720207253896,
#  'Java ME has become popular in mobile devices, where it competes with Symbian, BREW, and the .NET Compact Framework.': 0.13471502590673576,
#  'The diversity of mobile phone manufacturers has led to a need for new unified standards so programs can run on phones from different suppliers – MIDP.': 0.3471502590673575,
#  'The first standard was MIDP 1, which assumed a small screen size, no access to audio, and a 32 KB program limit.': 0.2227979274611399,
#  'The more recent MIDP 2 allows access to audio, and up to 64 KB for the program size.': 0.10880829015544041,
#  'With handset designs improving more rapidly than the standards, some manufacturers relax some limitations in the standards, for example, maximum program size.': 0.15544041450777205,
#  "Google's Android operating system uses the Java language, but not its class libraries, therefore the Android platform cannot be called Java.": 0.7512953367875648,
#  'Android, in all supported versions, executes the code on the ART VM (formerly the Dalvik VM up to Android 4.4.4) instead of the Java VM.': 0.27979274611398963,
#  'Open source communities have produced a large amount of software, including simple function libraries, development frameworks, and open source implementations of standards and tools.': 0.6683937823834196,
#  "Duke is Java's mascot.": 0.015544041450777202,
#  'A new Duke personality is created every year.': 0.12435233160621761,
#  'For example, in July 2011 "Future Tech Duke" included a bigger nose, a jetpack, and blue wings.': 0.07772020725388602,
#  "The source code for Sun's implementations of Java (i.e.": 0.27979274611398963,
#  'the de facto reference implementation) has been available for some time, but until recently,[when?]': 0.15544041450777202,
#  'the license terms severely restricted what could be done with it without signing (and generally paying for) a contract with Sun.': 0.1295336787564767,
#  'While several third-party projects (e.g.': 0.04145077720207254,
#  "These implementations also tended to be far less optimized than Sun's.": 0.16580310880829016,
#  'According to Richard Stallman, this would mean an end to the "Java trap".': 0.08808290155440414,
#  'Mark Shuttleworth called the initial press announcement, "A real milestone for the free software community".': 0.24870466321243526,
#  "Sun's goal was to replace the parts that remain proprietary and closed-source with alternative implementations and make the class library completely free and open source.": 0.46632124352331605,
#  'In the meantime, a third-party project called IcedTea created a completely free and highly usable JDK by replacing encumbered code with either stubs or code from GNU Classpath.': 0.5181347150259068,
#  'However OpenJDK has since become buildable without the encumbered parts (from OpenJDK 6 b10 ) and has become the default runtime environment for most Linux distributions.': 0.3316062176165803,
#  'In most cases, Java support is unnecessary in Web browsers, and security experts recommend that it not be run in a browser unless absolutely necessary.': 0.42487046632124353,
#  'It was suggested that, if Java is required by a few Web sites, users should have a separate browser installation specifically for those sites.': 0.21243523316062177,
#  'This limited the features that could be provided by this addition as compared to some other languages.': 0.20207253886010362,
#  'The addition of type wildcards made Java unsound.': 0.09326424870466321,
#  'Java lacks native unsigned integer types.': 0.17098445595854922,
#  'Unsigned data are often generated from programs written in C and the lack of these types prevents direct data interchange between C and Java.': 0.23834196891191706,
#  'Unsigned large numbers are also used in many numeric processing fields, including cryptography, which can make Java less convenient to use for these tasks.': 0.4870466321243524,
#  'Although it is possible to partially circumvent this problem with conversion code and using larger data types, it makes using Java cumbersome for handling the unsigned data.': 0.4300518134715026,
#  'While a 32-bit signed integer may be used to hold a 16-bit unsigned value with relative ease, a 32-bit unsigned value would require a 64-bit signed integer.': 0.30569948186528495,
#  'Additionally, a 64-bit unsigned value cannot be stored using any integer type in Java because no type larger than 64 bits exists in the Java language.': 0.37305699481865284,
#  'If abstracted using functions, function calls become necessary for many operations which are native to some other languages.': 0.3626943005181347,
#  "Alternatively, it is possible to use Java's signed integers to emulate unsigned integers of the same size, but this requires detailed knowledge of complex bitwise operations.": 0.26943005181347146,
#  'Additionally, the extended precision floating-point types permitted in 754 and present in many processors are not permitted in Java.': 0.1761658031088083,
#  'In the early days of Java (before the HotSpot VM was implemented in Java 1.3 in 2000) there were some criticisms of performance.': 0.08808290155440415,
#  'However, benchmarks typically report Java as being about 50% slower than C (a language which compiles to native code).': 0.43005181347150256,
#  "Java's performance has improved substantially since the early versions.": 0.13471502590673576,
#  'Performance of JIT compilers relative to native compilers has in some optimized tests been shown to be quite similar.': 0.18652849740932642,
#  'Interpretation is slower than native execution, and compilation at load time or runtime has an initial performance penalty for the compilation.': 0.300518134715026,
#  'Modern performant JVM implementations all use the compilation approach, so after the initial startup time the performance is equivalent to native code.': 0.5025906735751295,
#  'These flaws affect only Java applications which execute arbitrary untrusted bytecode, such as web browser plug-ins that run Java applets downloaded from public websites.': 0.4196891191709845,
#  'Applications where the user trusts, and has full control over, all code that is being executed are unaffected.': 0.2901554404145078,
#  'Java 5 was later found to be flawed as well.': 0.07772020725388601,
#  'On January 10, 2013, three computer specialists spoke out against Java, telling Reuters that it was not secure and that people should disable Java.': 0.12435233160621761,
#  'Jaime Blasco, Labs Manager with AlienVault Labs, stated that "Java is a mess.': 0.02590673575129534,
#  'It’s not secure.': 0.015544041450777202,
#  'You have to disable it."': 0.02072538860103627,
#  'This vulnerability affects Java 7 and it is unclear if it affects Java 6, so it is suggested that consumers disable it.': 0.09326424870466322,
#  'Security alerts from Oracle announce schedules of critical security-related patches to Java.': 0.10362694300518135,
#  'On January 14, 2013, security experts said that the update still failed to protect PCs from attack.': 0.16580310880829013,
#  'This exploit hole prompted a response from the United States Department of Homeland Security encouraging users to disable or uninstall Java.': 0.18134715025906736,
#  'Apple blacklisted Java in limited order for all computers running its macOS operating system through a virus protection program.': 0.22797927461139897,
#  'Responding to recent Java security and vulnerability issues, security blogger Brian Krebs has called for users to remove at least the Java browser plugin and also the entire software.': 0.5440414507772021,
#  '"Once promising, it has outlived its usefulness in the browser, and has become a nightmare that delights cyber-criminals at the expense of computer users."': 0.1865284974093264,
#  '"I think everyone should uninstall Java from all their PCs and Macs, and then think carefully about whether they need to add it back.': 0.10362694300518135,
#  'If you are a typical home user, you can probably do without it.': 0.11398963730569947,
#  'If you are a business user, you may not have a choice."': 0.0984455958549223,
#  'The Java runtime environment has a history of bundling sponsored software to be installed by default during installation and during the updates which roll out every month or so.': 0.2901554404145078,
#  'This includes the "Ask.com toolbar" that will redirect browser searches to ads and "McAfee Security Scan Plus".': 0.16580310880829016,
#  'These offers can be blocked through a setting in the Java Control Panel, although this is not obvious.': 0.06735751295336788,
#  'This setting is located under the "Advanced" tab in the Java Control Panel, under the "Miscellaneous" heading, where the option is labelled as an option to suppress "sponsor offers".': 0.10362694300518135,
#  'Java has yet to release an automatic updater that does not require user intervention and administrative rights unlike Google Chrome and Flash player.': 0.1813471502590673}

# %% [markdown]
# # SUMMARY

# %%
import heapq  
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)  
print(summary)
# Out:
# The use of bytecode as an intermediate language permits Java programs to run on any platform that has a virtual machine available. Google's Android operating system uses the Java language, but not its class libraries, therefore the Android platform cannot be called Java. Instead, the Java platform provides a comprehensive set of its own standard class libraries containing many of the same reusable functions commonly found in modern operating systems. By the summer of 1992, the team could demonstrate portions of the new platform, including the Green OS, the Oak language, the libraries, and the hardware. For these reasons, it is more of a transitional language to switch from Java to the .NET platform than it is a first class .NET language. Open source communities have produced a large amount of software, including simple function libraries, development frameworks, and open source implementations of standards and tools. For example, the Java compiler, which converts Java source code into Java bytecode (an intermediate language for the JVM), is provided as part of the Java Development Kit (JDK).
